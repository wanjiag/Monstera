# %%
import pandas as pd
from os.path import join as opj
import os 
from nipype.interfaces import fsl

from glob import glob
from nilearn.input_data import NiftiMasker
from nilearn.masking import intersect_masks

from nipype.interfaces.ants import ApplyTransforms
from nipype.interfaces.afni import TStat
import subprocess
# Out:
# 220505-13:14:52,802 nipype.utils WARNING:
# 	 A newer version (1.7.1) of nipy/nipype is available. You are using 1.7.0
# /home/wanjiag/.local/lib/python3.6/site-packages/nilearn/datasets/__init__.py:96: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   "Numpy arrays.", FutureWarning)

# %%
######## Functions ########

def sh(script):
    os.system("bash -c '%s'" % script)
    
    
def mask_rois(in_file, brain_mask, file_name):
    
    out_file = opj(output_dir, '{}_thre_{}_masked.nii.gz'.format(file_name,epi_mask_threshold))
    
    masked = intersect_masks([in_file, brain_mask], threshold=1, connected=False)
    masked.to_filename(out_file)
    
    return out_file
    
def coreg_2_epi(in_file, file_name):
    
    # Coregister any map into the epi space
    flt_out_file = opj(output_dir, '{}.nii.gz'.format(file_name))

    flt = fsl.FLIRT(in_file = in_file,
                    reference = avg_run_file,
                    apply_xfm = True,
                    uses_qform = True,
                    out_matrix_file = opj(output_dir, '{}.mat'.format(file_name)),
                    out_file = flt_out_file
                   )
    print(flt.cmdline)
    flt.run()

    # Threshold the epi space mask so it fits the original mask better and binarizes the mask
    trh_out_file = opj(output_dir, '{}_thre_{}.nii.gz'.format(file_name,epi_mask_threshold))
    trh = fsl.Threshold(thresh = epi_mask_threshold,
                        in_file = flt_out_file,
                        args = '-bin',
                        out_file = trh_out_file
                   )
    print(trh.cmdline)
    trh.run()
    
    masked_out_file = mask_rois(trh_out_file, brain_mask, file_name)
    
    return masked_out_file

def calculate_mean(in_file, file_name):
    ## Calculate mean images
    print('calculating mean......')
    #mean_img = mean_img(trim_output, target_affine=None, target_shape=None, verbose=0, n_jobs=1)
    mean_output = file_name
    #mean_img.to_filename(mean_output)
    tstat = TStat()
    tstat.inputs.in_file = in_file
    tstat.inputs.args = '-mean'
    tstat.inputs.out_file = mean_output
    print(tstat.cmdline)
    res = tstat.run() 

    print('calculating mean...output to %s'%(mean_output))

# %%
######## Running ########

derivative_dir = '/projects/kuhl_lab/wanjiag/MONSTERA/derivatives/'
preprocess_base_dir = opj(derivative_dir, 'preprocess/')
fmriprep_base_dir = opj(derivative_dir, 'fmriprep/')
automatic_detecting_subjects = False

if automatic_detecting_subjects:
    f_list = [x for x in glob(os.path.join(fmriprep_base_dir, '*sub-MONSTERA*/'))]
    subs = list(map(lambda f: f[len(os.path.commonpath(f_list))+1:-1], f_list))
    subs.sort()
    print(subs)
else:
    subs = ['sub-MONSTERA01']
    
session_list = []
for i in range(1,11):
    session_list.append('task-{:02d}'.format(i))

epi_mask_threshold = 0.5

# %%
subnum = subs[0]

# %%
subnum
# Out:
# 'sub-MONSTERA01'

# %%
output_dir = opj(derivative_dir, 'rois', subnum)

if not os.path.isdir(output_dir):
    os.makedirs(output_dir)

fmriprep_dir = opj(fmriprep_base_dir, subnum)
preprocess_dir = opj(preprocess_base_dir, subnum)

print('--------------------{}-------------------'.format(subnum))
print(output_dir)
# Out:
# --------------------sub-MONSTERA01-------------------
# /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01

# %%
preprocess_dir
# Out:
# '/projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01'

# %%
# Getting brain mask
brain_mask = opj(preprocess_dir, '{}_space-T1w_desc-brain_intersect_mask.nii.gz'.format(subnum))

# Finding and coverting aparc into nifti file.
mgz_file = opj(fmriprep_base_dir, 'sourcedata', 'freesurfer', subnum, 'mri', 'aparc.a2009s+aseg.mgz')
gii_file = opj(output_dir, 'aparc.a2009s+aseg.nii.gz'.format(subnum))
print(mgz_file)
print(gii_file)
p = subprocess.run(['mri_convert', mgz_file, gii_file],stdout=subprocess.PIPE)
p.stdout
# Out:
# /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/fmriprep/sourcedata/freesurfer/sub-MONSTERA01/mri/aparc.a2009s+aseg.mgz
# /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/aparc.a2009s+aseg.nii.gz
# b'mri_convert /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/fmriprep/sourcedata/freesurfer/sub-MONSTERA01/mri/aparc.a2009s+aseg.mgz /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/aparc.a2009s+aseg.nii.gz \nreading from /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/fmriprep/sourcedata/freesurfer/sub-MONSTERA01/mri/aparc.a2009s+aseg.mgz...\nTR=2500.00, TE=0.00, TI=0.00, flip angle=0.00\ni_ras = (-1, -4.65661e-10, 0)\nj_ras = (0, -7.45058e-09, -1)\nk_ras = (1.86265e-09, 1, -7.45058e-09)\nwriting to /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/aparc.a2009s+aseg.nii.gz...\n'

# %%
    # Finding and copying aparcaseg file into ROIs folder
    aparc_file = os.path.join(fmriprep_dir,'anat','{}_run-5_desc-aparcaseg_dseg.nii.gz'.format(subnum))
    aparc_output = os.path.join(output_dir, 'run-5_desc-aparcaseg_dseg.nii.gz'.format(subnum))
    print(aparc_file)
    print(aparc_output)
    p = subprocess.run(['cp', aparc_file, aparc_output],stdout=subprocess.PIPE)
    p.stdout
# Out:
# /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/fmriprep/sub-MONSTERA01/anat/sub-MONSTERA01_run-5_desc-aparcaseg_dseg.nii.gz
# /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/run-5_desc-aparcaseg_dseg.nii.gz
# b''

# %%
    # Calculate All runs average as a reference image
    avg_run_file = opj(output_dir, 'avg_all_fmriprerp_func.nii.gz')
    if not os.path.exists(avg_run_file): 
        add_string = ''
        for session in session_list:
            in_file = opj(preprocess_dir, '{}_{}_desc-preproc_bold_trim6_denoise_z-scored.nii.gz'.format(subnum, session))
            file_name = opj(output_dir, '{}_{}_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz'.format(subnum, session))
            calculate_mean(in_file, file_name)

            if session == session_list[0]:
                continue
            add_string += '-add {} '.format(file_name)

        add_string += '-div {}'.format(len(session_list))
        in_file  = opj(output_dir, '{}_{}_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz'.format(subnum, session_list[0]))
        maths = fsl.ImageMaths(in_file=in_file, 
                                op_string=add_string,
                                out_file=avg_run_file)
        print(maths.cmdline)
        maths.run()
        
        sh('rm {}/*desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz'.format(output_dir))
# Out:
# calculating mean......
# 3dTstat -mean -prefix /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-01_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-01_desc-preproc_bold_trim6_denoise_z-scored.nii.gz
# 220505-13:17:00,617 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:00.617094:++ 3dTstat: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# 220505-13:17:00,619 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:00.617094:++ Authored by: KR Hammett & RW Cox
# 220505-13:17:00,777 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:00.777864:** AFNI converts NIFTI_datatype=64 (FLOAT64) in file /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-01_desc-preproc_bold_trim6_denoise_z-scored.nii.gz to FLOAT32
# 220505-13:17:00,780 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:00.777864:     Warnings of this type will be muted for this session.
# 220505-13:17:00,782 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:00.777864:     Set AFNI_NIFTI_TYPE_WARN to YES to see them all, NO to see none.
# 220505-13:17:16,131 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:16.131193:++ Output dataset /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-01_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean...output to /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-01_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean......
# 3dTstat -mean -prefix /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-02_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-02_desc-preproc_bold_trim6_denoise_z-scored.nii.gz
# 220505-13:17:16,258 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:16.258055:++ 3dTstat: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# 220505-13:17:16,260 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:16.258055:++ Authored by: KR Hammett & RW Cox
# 220505-13:17:16,311 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:16.311084:** AFNI converts NIFTI_datatype=64 (FLOAT64) in file /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-02_desc-preproc_bold_trim6_denoise_z-scored.nii.gz to FLOAT32
# 220505-13:17:16,312 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:16.311084:     Warnings of this type will be muted for this session.
# 220505-13:17:16,314 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:16.311084:     Set AFNI_NIFTI_TYPE_WARN to YES to see them all, NO to see none.
# 220505-13:17:31,123 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:31.123831:++ Output dataset /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-02_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean...output to /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-02_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean......
# 3dTstat -mean -prefix /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-03_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-03_desc-preproc_bold_trim6_denoise_z-scored.nii.gz
# 220505-13:17:31,242 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:31.242388:++ 3dTstat: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# 220505-13:17:31,245 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:31.242388:++ Authored by: KR Hammett & RW Cox
# 220505-13:17:31,299 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:31.299862:** AFNI converts NIFTI_datatype=64 (FLOAT64) in file /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-03_desc-preproc_bold_trim6_denoise_z-scored.nii.gz to FLOAT32
# 220505-13:17:31,301 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:31.299862:     Warnings of this type will be muted for this session.
# 220505-13:17:31,303 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:31.299862:     Set AFNI_NIFTI_TYPE_WARN to YES to see them all, NO to see none.
# 220505-13:17:46,7 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:46.007175:++ Output dataset /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-03_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean...output to /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-03_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean......
# 3dTstat -mean -prefix /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-04_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-04_desc-preproc_bold_trim6_denoise_z-scored.nii.gz
# 220505-13:17:46,161 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:46.160914:++ 3dTstat: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# 220505-13:17:46,164 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:46.160914:++ Authored by: KR Hammett & RW Cox
# 220505-13:17:46,212 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:46.212108:** AFNI converts NIFTI_datatype=64 (FLOAT64) in file /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-04_desc-preproc_bold_trim6_denoise_z-scored.nii.gz to FLOAT32
# 220505-13:17:46,213 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:46.212108:     Warnings of this type will be muted for this session.
# 220505-13:17:46,215 nipype.interface INFO:
# 	 stderr 2022-05-05T13:17:46.212108:     Set AFNI_NIFTI_TYPE_WARN to YES to see them all, NO to see none.
# 220505-13:18:00,964 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:00.964458:++ Output dataset /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-04_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean...output to /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-04_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean......
# 3dTstat -mean -prefix /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-05_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-05_desc-preproc_bold_trim6_denoise_z-scored.nii.gz
# 220505-13:18:01,129 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:01.129550:++ 3dTstat: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# 220505-13:18:01,133 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:01.129550:++ Authored by: KR Hammett & RW Cox
# 220505-13:18:01,194 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:01.194147:** AFNI converts NIFTI_datatype=64 (FLOAT64) in file /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-05_desc-preproc_bold_trim6_denoise_z-scored.nii.gz to FLOAT32
# 220505-13:18:01,195 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:01.194147:     Warnings of this type will be muted for this session.
# 220505-13:18:01,197 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:01.194147:     Set AFNI_NIFTI_TYPE_WARN to YES to see them all, NO to see none.
# 220505-13:18:15,910 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:15.910035:++ Output dataset /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-05_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean...output to /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-05_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean......
# 3dTstat -mean -prefix /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-06_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-06_desc-preproc_bold_trim6_denoise_z-scored.nii.gz
# 220505-13:18:16,73 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:16.073069:++ 3dTstat: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# 220505-13:18:16,76 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:16.073069:++ Authored by: KR Hammett & RW Cox
# 220505-13:18:16,114 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:16.114828:** AFNI converts NIFTI_datatype=64 (FLOAT64) in file /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-06_desc-preproc_bold_trim6_denoise_z-scored.nii.gz to FLOAT32
# 220505-13:18:16,116 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:16.114828:     Warnings of this type will be muted for this session.
# 220505-13:18:16,118 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:16.114828:     Set AFNI_NIFTI_TYPE_WARN to YES to see them all, NO to see none.
# 220505-13:18:30,844 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:30.843938:++ Output dataset /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-06_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean...output to /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-06_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean......
# 3dTstat -mean -prefix /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-07_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-07_desc-preproc_bold_trim6_denoise_z-scored.nii.gz
# 220505-13:18:30,961 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:30.961356:++ 3dTstat: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# 220505-13:18:30,964 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:30.961356:++ Authored by: KR Hammett & RW Cox
# 220505-13:18:31,54 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:31.054933:** AFNI converts NIFTI_datatype=64 (FLOAT64) in file /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-07_desc-preproc_bold_trim6_denoise_z-scored.nii.gz to FLOAT32
# 220505-13:18:31,56 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:31.054933:     Warnings of this type will be muted for this session.
# 220505-13:18:31,58 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:31.054933:     Set AFNI_NIFTI_TYPE_WARN to YES to see them all, NO to see none.
# 220505-13:18:45,781 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:45.781791:++ Output dataset /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-07_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean...output to /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-07_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean......
# 3dTstat -mean -prefix /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-08_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-08_desc-preproc_bold_trim6_denoise_z-scored.nii.gz
# 220505-13:18:45,904 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:45.904480:++ 3dTstat: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# 220505-13:18:45,907 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:45.904480:++ Authored by: KR Hammett & RW Cox
# 220505-13:18:45,960 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:45.960077:** AFNI converts NIFTI_datatype=64 (FLOAT64) in file /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-08_desc-preproc_bold_trim6_denoise_z-scored.nii.gz to FLOAT32
# 220505-13:18:45,961 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:45.960077:     Warnings of this type will be muted for this session.
# 220505-13:18:45,963 nipype.interface INFO:
# 	 stderr 2022-05-05T13:18:45.960077:     Set AFNI_NIFTI_TYPE_WARN to YES to see them all, NO to see none.
# 220505-13:19:00,737 nipype.interface INFO:
# 	 stderr 2022-05-05T13:19:00.737359:++ Output dataset /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-08_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean...output to /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-08_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean......
# 3dTstat -mean -prefix /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-09_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-09_desc-preproc_bold_trim6_denoise_z-scored.nii.gz
# 220505-13:19:00,855 nipype.interface INFO:
# 	 stderr 2022-05-05T13:19:00.855478:++ 3dTstat: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# 220505-13:19:00,858 nipype.interface INFO:
# 	 stderr 2022-05-05T13:19:00.855478:++ Authored by: KR Hammett & RW Cox
# 220505-13:19:00,901 nipype.interface INFO:
# 	 stderr 2022-05-05T13:19:00.901805:** AFNI converts NIFTI_datatype=64 (FLOAT64) in file /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-09_desc-preproc_bold_trim6_denoise_z-scored.nii.gz to FLOAT32
# 220505-13:19:00,903 nipype.interface INFO:
# 	 stderr 2022-05-05T13:19:00.901805:     Warnings of this type will be muted for this session.
# 220505-13:19:00,905 nipype.interface INFO:
# 	 stderr 2022-05-05T13:19:00.901805:     Set AFNI_NIFTI_TYPE_WARN to YES to see them all, NO to see none.
# 220505-13:19:15,675 nipype.interface INFO:
# 	 stderr 2022-05-05T13:19:15.675297:++ Output dataset /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-09_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean...output to /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-09_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean......
# 3dTstat -mean -prefix /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-10_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-10_desc-preproc_bold_trim6_denoise_z-scored.nii.gz
# 220505-13:19:15,797 nipype.interface INFO:
# 	 stderr 2022-05-05T13:19:15.796963:++ 3dTstat: AFNI version=AFNI_18.2.04 (Jul  6 2018) [64-bit]
# 220505-13:19:15,799 nipype.interface INFO:
# 	 stderr 2022-05-05T13:19:15.796963:++ Authored by: KR Hammett & RW Cox
# 220505-13:19:15,851 nipype.interface INFO:
# 	 stderr 2022-05-05T13:19:15.851790:** AFNI converts NIFTI_datatype=64 (FLOAT64) in file /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/preprocess/sub-MONSTERA01/sub-MONSTERA01_task-10_desc-preproc_bold_trim6_denoise_z-scored.nii.gz to FLOAT32
# 220505-13:19:15,853 nipype.interface INFO:
# 	 stderr 2022-05-05T13:19:15.851790:     Warnings of this type will be muted for this session.
# 220505-13:19:15,853 nipype.interface INFO:
# 	 stderr 2022-05-05T13:19:15.851790:     Set AFNI_NIFTI_TYPE_WARN to YES to see them all, NO to see none.
# 220505-13:19:30,610 nipype.interface INFO:
# 	 stderr 2022-05-05T13:19:30.610127:++ Output dataset /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-10_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# calculating mean...output to /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-10_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz
# fslmaths /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-01_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz -add /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-02_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz -add /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-03_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz -add /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-04_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz -add /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-05_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz -add /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-06_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz -add /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-07_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz -add /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-08_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz -add /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-09_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz -add /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/sub-MONSTERA01_task-10_desc-preproc_bold_trim6_denoise_z-scored_mean.nii.gz -div 10 /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/avg_all_fmriprerp_func.nii.gz

# %%
    print('--------------------Angular Gyrus-------------------')
    ag = {'ctx_lh_G_pariet_inf-Angular':11125,
          'ctx_rh_G_pariet_inf-Angular':12125}

    for i in ag:
        op_string = '-thr {} -uthr {}'.format(ag[i],ag[i])
        out_file = opj(output_dir, '{}.nii.gz'.format(i))

        maths = fsl.ImageMaths(in_file=gii_file, 
                                op_string=op_string,
                                out_file=out_file)
        print(maths.cmdline)
        maths.run() 
    
    in_file  = opj(output_dir, 'ctx_lh_G_pariet_inf-Angular.nii.gz')
    op_string = '-add {} -bin'.format(opj(output_dir, 'ctx_rh_G_pariet_inf-Angular.nii.gz'))

    out_file = opj(output_dir, 'angular_gyrus.nii.gz'.format(i))
    maths = fsl.ImageMaths(in_file=in_file, 
                            op_string=op_string,
                            out_file=out_file)
    print(maths.cmdline)
    maths.run()
    
    sh('rm {}/ctx_*_G_pariet_inf-Angular.nii.gz'.format(output_dir))
    
    coreg_2_epi(out_file, 'angular_gyrus_2_epi')
# Out:
# --------------------Angular Gyrus-------------------
# fslmaths /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/aparc.a2009s+aseg.nii.gz -thr 11125 -uthr 11125 /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/ctx_lh_G_pariet_inf-Angular.nii.gz
# fslmaths /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/aparc.a2009s+aseg.nii.gz -thr 12125 -uthr 12125 /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/ctx_rh_G_pariet_inf-Angular.nii.gz
# fslmaths /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/ctx_lh_G_pariet_inf-Angular.nii.gz -add /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/ctx_rh_G_pariet_inf-Angular.nii.gz -bin /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/angular_gyrus.nii.gz
# flirt -in /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/angular_gyrus.nii.gz -ref /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/avg_all_fmriprerp_func.nii.gz -out /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/angular_gyrus_2_epi.nii.gz -omat /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/angular_gyrus_2_epi.mat -applyxfm -usesqform
# fslmaths /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/angular_gyrus_2_epi.nii.gz -thr 0.5000000000 -bin /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/angular_gyrus_2_epi_thre_0.5.nii.gz
# '/projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/angular_gyrus_2_epi_thre_0.5_masked.nii.gz'

# %%
    # Whole Hippocampus
    print('--------------------Whole Hippocampus-------------------')
    hippo = {'Left-Hippocampus':17,
             'Right-Hippocampus':53}
    for i in hippo:
        op_string = '-thr {} -uthr {}'.format(hippo[i],hippo[i])
        out_file = opj(output_dir, '{}.nii.gz'.format(i))

        maths = fsl.ImageMaths(in_file=aparc_output, 
                                op_string=op_string,
                                out_file=out_file)
        print(maths.cmdline)
        maths.run()

    in_file  = opj(output_dir, 'Left-Hippocampus.nii.gz')
    op_string = '-add {} -bin'.format(opj(output_dir, 'Right-Hippocampus.nii.gz'))

    out_file = opj(output_dir, 'hippocampus.nii.gz'.format(i))
    maths = fsl.ImageMaths(in_file=in_file, 
                            op_string=op_string,
                            out_file=out_file)
    print(maths.cmdline)
    maths.run()

    sh('rm {}/*-Hippocampus.nii.gz'.format(output_dir))
    
    coreg_2_epi(out_file, 'hippocampus_2_epi')
# Out:
# --------------------Whole Hippocampus-------------------
# fslmaths /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/run-5_desc-aparcaseg_dseg.nii.gz -thr 17 -uthr 17 /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/Left-Hippocampus.nii.gz
# fslmaths /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/run-5_desc-aparcaseg_dseg.nii.gz -thr 53 -uthr 53 /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/Right-Hippocampus.nii.gz
# fslmaths /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/Left-Hippocampus.nii.gz -add /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/Right-Hippocampus.nii.gz -bin /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/hippocampus.nii.gz
# flirt -in /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/hippocampus.nii.gz -ref /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/avg_all_fmriprerp_func.nii.gz -out /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/hippocampus_2_epi.nii.gz -omat /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/hippocampus_2_epi.mat -applyxfm -usesqform
# fslmaths /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/hippocampus_2_epi.nii.gz -thr 0.5000000000 -bin /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/hippocampus_2_epi_thre_0.5.nii.gz
# '/projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/hippocampus_2_epi_thre_0.5_masked.nii.gz'

# %%
    # PPA from MNI space
    print('--------------------PPA-------------------')
    ppa_mni = '/home/wanjiag/projects/MONSTERA/derivatives/rois/mni/ppa/ppa.nii.gz'
    h5 = opj(fmriprep_dir, 'anat/{}_run-5_from-MNI152NLin2009cAsym_to-T1w_mode-image_xfm.h5'.format(subnum))

    print(ppa_mni, '\n', avg_run_file, '\n', h5, '\n', output_dir)
    
    at = ApplyTransforms(input_image = ppa_mni,
                         dimension = 3,
                         reference_image = avg_run_file,
                         float = False,
                         transforms = h5,
                         output_image = opj(output_dir, 'ppa_mni_2_epi.nii.gz')
                        )
    print(at.cmdline)
    command = "module load singularity; singularity exec --bind /projects/kuhl_lab/wanjiag/MONSTERA/derivatives:/projects/kuhl_lab/wanjiag/MONSTERA/derivatives /gpfs/projects/kuhl_lab/shared/containers/fmriprep-21.0.1.simg {}".format(at.cmdline)

    p = subprocess.run(command, shell=True, stdout=subprocess.PIPE)
    p.stdout
    
    ppa_output = opj(output_dir, 'ppa_mni_2_epi.nii.gz')
    
    trh_out_file = opj(output_dir, 
                       'ppa_mni_2_epi_thr_{}.nii.gz'.format(epi_mask_threshold))
    trh = fsl.Threshold(thresh = epi_mask_threshold,
                        in_file = ppa_output,
                        args = '-bin',
                        out_file = trh_out_file
                   )
    print(trh.cmdline)
    trh.run()
    
    mask_rois(trh_out_file, brain_mask, 'ppa_mni_2_epi')
# Out:
# --------------------PPA-------------------
# /home/wanjiag/projects/MONSTERA/derivatives/rois/mni/ppa/ppa.nii.gz
#  /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/avg_all_fmriprerp_func.nii.gz
#  /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/fmriprep/sub-MONSTERA01/anat/sub-MONSTERA01_run-5_from-MNI152NLin2009cAsym_to-T1w_mode-image_xfm.h5
#  /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01
# antsApplyTransforms --default-value 0 --dimensionality 3 --float 0 --input /home/wanjiag/projects/MONSTERA/derivatives/rois/mni/ppa/ppa.nii.gz --interpolation Linear --output /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/ppa_mni_2_epi.nii.gz --reference-image /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/avg_all_fmriprerp_func.nii.gz --transform /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/fmriprep/sub-MONSTERA01/anat/sub-MONSTERA01_run-5_from-MNI152NLin2009cAsym_to-T1w_mode-image_xfm.h5
# fslmaths /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/ppa_mni_2_epi.nii.gz -thr 0.5000000000 -bin /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/ppa_mni_2_epi_thr_0.5.nii.gz
# '/projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/ppa_mni_2_epi_thre_0.5_masked.nii.gz'

# %%
    # EVC from MNI space
    print('--------------------EVC-------------------')
    ev_mni_path = '/home/wanjiag/projects/MONSTERA/derivatives/rois/mni/visual_cortex/subj_vol_all'
    ev_files = ['perc_VTPM_vol_roi1_lh.nii.gz',
                'perc_VTPM_vol_roi1_rh.nii.gz',
                'perc_VTPM_vol_roi2_lh.nii.gz',
                'perc_VTPM_vol_roi2_rh.nii.gz']

    print(ev_mni_path, '\n', avg_run_file, '\n', h5, '\n', output_dir)
    
    ev_file_threshold = 50
    ev_output = []
    cmdline = []

    for ev_file in ev_files:
        at_out_file = opj(output_dir, '{}_2_epi.nii.gz'.format(ev_file.split('.')[0]))
        at = ApplyTransforms(input_image = opj(ev_mni_path,ev_file),
                             dimension = 3,
                             reference_image = avg_run_file,
                             float = False,
                             transforms = h5,
                             output_image = at_out_file
                            )
        print(at.cmdline)
        command = "module load singularity;singularity exec --bind /projects/kuhl_lab/wanjiag/MONSTERA/derivatives:/projects/kuhl_lab/wanjiag/MONSTERA/derivatives /gpfs/projects/kuhl_lab/shared/containers/fmriprep-21.0.1.simg {}".format(at.cmdline)
        p = subprocess.run(command, shell=True, stdout=subprocess.PIPE)
        p.stdout

        trh_out_file = opj(output_dir, '{}_2_epi_thr_{}.nii.gz'.format(ev_file.split('.')[0], ev_file_threshold))
        trh = fsl.Threshold(thresh = ev_file_threshold,
                            in_file = at_out_file,
                            args = '-bin',
                            out_file = trh_out_file
                       )
        print(trh.cmdline)
        trh.run()

        ev_output.append(trh_out_file)

        
    in_file  = opj(output_dir, ev_output[0])
    ev_add = ev_output[1:]
    op_string = ''

    for ev in ev_add:
        op_string += '-add {} '.format(ev)

    op_string += '-bin'
    out_file = opj(output_dir, 'evc_2_epi_thr_0.5.nii.gz')
    maths = fsl.ImageMaths(in_file=in_file, 
                            op_string=op_string,
                            out_file=out_file)
    print(maths.cmdline)
    maths.run()
    sh('rm {}/perc_VTPM_vol_roi*'.format(output_dir))
    
    mask_rois(out_file, brain_mask, 'evc_2_epi')
# Out:
# --------------------EVC-------------------
# /home/wanjiag/projects/MONSTERA/derivatives/rois/mni/visual_cortex/subj_vol_all
#  /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/avg_all_fmriprerp_func.nii.gz
#  /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/fmriprep/sub-MONSTERA01/anat/sub-MONSTERA01_run-5_from-MNI152NLin2009cAsym_to-T1w_mode-image_xfm.h5
#  /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01
# antsApplyTransforms --default-value 0 --dimensionality 3 --float 0 --input /home/wanjiag/projects/MONSTERA/derivatives/rois/mni/visual_cortex/subj_vol_all/perc_VTPM_vol_roi1_lh.nii.gz --interpolation Linear --output /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/perc_VTPM_vol_roi1_lh_2_epi.nii.gz --reference-image /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/avg_all_fmriprerp_func.nii.gz --transform /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/fmriprep/sub-MONSTERA01/anat/sub-MONSTERA01_run-5_from-MNI152NLin2009cAsym_to-T1w_mode-image_xfm.h5
# fslmaths /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/perc_VTPM_vol_roi1_lh_2_epi.nii.gz -thr 50.0000000000 -bin /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/perc_VTPM_vol_roi1_lh_2_epi_thr_50.nii.gz
# antsApplyTransforms --default-value 0 --dimensionality 3 --float 0 --input /home/wanjiag/projects/MONSTERA/derivatives/rois/mni/visual_cortex/subj_vol_all/perc_VTPM_vol_roi1_rh.nii.gz --interpolation Linear --output /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/perc_VTPM_vol_roi1_rh_2_epi.nii.gz --reference-image /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/avg_all_fmriprerp_func.nii.gz --transform /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/fmriprep/sub-MONSTERA01/anat/sub-MONSTERA01_run-5_from-MNI152NLin2009cAsym_to-T1w_mode-image_xfm.h5
# fslmaths /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/perc_VTPM_vol_roi1_rh_2_epi.nii.gz -thr 50.0000000000 -bin /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/perc_VTPM_vol_roi1_rh_2_epi_thr_50.nii.gz
# antsApplyTransforms --default-value 0 --dimensionality 3 --float 0 --input /home/wanjiag/projects/MONSTERA/derivatives/rois/mni/visual_cortex/subj_vol_all/perc_VTPM_vol_roi2_lh.nii.gz --interpolation Linear --output /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/perc_VTPM_vol_roi2_lh_2_epi.nii.gz --reference-image /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/avg_all_fmriprerp_func.nii.gz --transform /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/fmriprep/sub-MONSTERA01/anat/sub-MONSTERA01_run-5_from-MNI152NLin2009cAsym_to-T1w_mode-image_xfm.h5
# fslmaths /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/perc_VTPM_vol_roi2_lh_2_epi.nii.gz -thr 50.0000000000 -bin /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/perc_VTPM_vol_roi2_lh_2_epi_thr_50.nii.gz
# antsApplyTransforms --default-value 0 --dimensionality 3 --float 0 --input /home/wanjiag/projects/MONSTERA/derivatives/rois/mni/visual_cortex/subj_vol_all/perc_VTPM_vol_roi2_rh.nii.gz --interpolation Linear --output /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/perc_VTPM_vol_roi2_rh_2_epi.nii.gz --reference-image /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/avg_all_fmriprerp_func.nii.gz --transform /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/fmriprep/sub-MONSTERA01/anat/sub-MONSTERA01_run-5_from-MNI152NLin2009cAsym_to-T1w_mode-image_xfm.h5
# fslmaths /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/perc_VTPM_vol_roi2_rh_2_epi.nii.gz -thr 50.0000000000 -bin /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/perc_VTPM_vol_roi2_rh_2_epi_thr_50.nii.gz
# fslmaths /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/perc_VTPM_vol_roi1_lh_2_epi_thr_50.nii.gz -add /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/perc_VTPM_vol_roi1_rh_2_epi_thr_50.nii.gz -add /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/perc_VTPM_vol_roi2_lh_2_epi_thr_50.nii.gz -add /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/perc_VTPM_vol_roi2_rh_2_epi_thr_50.nii.gz -bin /projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/evc_2_epi_thr_0.5.nii.gz
# '/projects/kuhl_lab/wanjiag/MONSTERA/derivatives/rois/sub-MONSTERA01/evc_2_epi_thre_0.5_masked.nii.gz'
